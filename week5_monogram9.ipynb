# %%
import pandas as pd
df=pd.read_csv("df.csv")
df
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2                         Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                                 Data Analyst  $111K-$181K (Glassdoor est.)
# 4                       Director, Data Science  $111K-$181K (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer  $42K - $76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer            $65 - $72 Per Hour
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5892 entries, 0 to 5891
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          5892 non-null   object
#  1   Salary Estimate    5892 non-null   object
#  2   Rating             5892 non-null   float64
#  3   Company Name       5892 non-null   object
#  4   Location           5892 non-null   object
#  5   Size               5892 non-null   object
#  6   Founded            5892 non-null   object
#  7   Type of ownership  5892 non-null   object
#  8   Industry           5892 non-null   object
#  9   Sector             5892 non-null   object
#  10  Revenue            5892 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 506.5+ KB

# %%
df.head()
# Out:
#                            Job Title               Salary Estimate  Rating  \
# 0              Senior Data Scientist  $111K-$181K (Glassdoor est.)     3.5
# 1  Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)     4.5
# 2               Data Science Manager  $111K-$181K (Glassdoor est.)    -1.0
# 3                       Data Analyst  $111K-$181K (Glassdoor est.)     3.4
# 4             Director, Data Science  $111K-$181K (Glassdoor est.)     3.4
#
#                       Company Name       Location                    Size  \
# 0                      Hopper\n3.5   New York, NY   501 to 1000 employees
# 1                     Noom US\n4.5   New York, NY  1001 to 5000 employees
# 2                         Decode_M   New York, NY       1 to 50 employees
# 3            Sapphire Digital\n3.4  Lyndhurst, NJ    201 to 500 employees
# 4  United Entertainment Group\n3.4   New York, NY     51 to 200 employees
#
#   Founded  Type of ownership                   Industry  \
# ...

# %%
df['Company Name'].value_counts()
# Out:
# Company Name
# Apple\n4.1                                     60
# IBM\n3.7                                       57
# Amazon\n3.9                                    47
# Amazon Web Services, Inc.\n3.8                 30
# Staffigo Technical Services, LLC\n5.0          28
#                                                ..
# American Specialty Health Incorporated\n2.9     1
# Samsung Electronics America\n2.9                1
# Quidel Corporation\n2.6                         1
# University of California\n4.2                   1
# AE Business Solutions\n4.0                      1
# Name: count, Length: 3279, dtype: int64

# %%
df.drop(['Salary Estimate' ,'Rating'] , axis=1)
# Out:
#                                      Job Title  \
# 0                        Senior Data Scientist
# 1            Data Scientist, Product Analytics
# 2                         Data Science Manager
# 3                                 Data Analyst
# 4                       Director, Data Science
# ...                                        ...
# 5887       Manufacturing Data Analyst Engineer
# 5888                            Data Scientist
# 5889  Supply Chain Consultant - Data Scientist
# 5890                     Data Science Engineer
# 5891      Data Scientist/ Full Stack Developer
#
#                               Company Name       Location  \
# 0                              Hopper\n3.5   New York, NY
# 1                             Noom US\n4.5   New York, NY
# 2                                 Decode_M   New York, NY
# 3                    Sapphire Digital\n3.4  Lyndhurst, NJ
# 4          United Entertainment Group\n3.4   New York, NY
# ...

# %%
df['Size'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Size'>

# %%
df['Rating'].value_counts().plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Salary Estimate'][0]
# Out:
# '$111K-$181K (Glassdoor est.)'

# %%
df['Rating'].apply(int)
# Out:
# 0       3
# 1       4
# 2      -1
# 3       3
# 4       3
#        ..
# 5887    3
# 5888    4
# 5889    4
# 5890    4
# 5891    3
# Name: Rating, Length: 5892, dtype: int64

# %%
df['Salary Estimate'][0].replace("$","")
# Out:
# '111K-181K (Glassdoor est.)'

# %%
def dollor_remover(a):
    a=a.replace("$"," ")
    return a
dollor_remover(df['Salary Estimate'][0])
df['Salary Estimate']=df['Salary Estimate'].apply(dollor_remover)
df
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist   111K- 181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics   111K- 181K (Glassdoor est.)
# 2                         Data Science Manager   111K- 181K (Glassdoor est.)
# 3                                 Data Analyst   111K- 181K (Glassdoor est.)
# 4                       Director, Data Science   111K- 181K (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer   42K -  76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer             65 -  72 Per Hour
#
# ...

# %%
def k_remover(a):
    a=a.replace("K"," ")
    return a
df['Salary Estimate']=df['Salary Estimate'].apply(k_remover)
df
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist   111 - 181  (Glassdoor est.)
# 1            Data Scientist, Product Analytics   111 - 181  (Glassdoor est.)
# 2                         Data Science Manager   111 - 181  (Glassdoor est.)
# 3                                 Data Analyst   111 - 181  (Glassdoor est.)
# 4                       Director, Data Science   111 - 181  (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer   42  -  76  (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer             65 -  72 Per Hour
#
# ...

# %%
df=df[df['Salary Estimate']!="-1"]
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
# 5891               Data Scientist/ Full Stack Developer
#
#                     Salary Estimate  Rating  \
# 0       111 - 181  (Glassdoor est.)     3.5
# 1       111 - 181  (Glassdoor est.)     4.5
# 2       111 - 181  (Glassdoor est.)    -1.0
# 3       111 - 181  (Glassdoor est.)     3.4
# 4       111 - 181  (Glassdoor est.)     3.4
# ...

# %%
df=df[~df['Salary Estimate'].str.contains("Per Hour")]
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5881                              Information Scientist
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
#
#                     Salary Estimate  Rating  \
# 0       111 - 181  (Glassdoor est.)     3.5
# 1       111 - 181  (Glassdoor est.)     4.5
# 2       111 - 181  (Glassdoor est.)    -1.0
# 3       111 - 181  (Glassdoor est.)     3.4
# 4       111 - 181  (Glassdoor est.)     3.4
# ...

# %%
df[df['Founded']=='2007']
# Out:
#                                          Job Title  \
# 0                            Senior Data Scientist
# 4                           Director, Data Science
# 110                                 Data Scientist
# 132                                 Data Scientist
# 144   Quantitative Researcher - Portfolio Modeling
# ...                                            ...
# 5196                                  Data Analyst
# 5204                          Junior Data Engineer
# 5387                                Data Scientist
# 5568                 Business Intelligence Analyst
# 5658                       Data Scientist (remote)
#
#                     Salary Estimate  Rating  \
# 0       111 - 181  (Glassdoor est.)     3.5
# 4       111 - 181  (Glassdoor est.)     3.4
# 110     102 - 121  (Glassdoor est.)     4.0
# 132     102 - 121  (Glassdoor est.)     3.6
# 144     129 - 210  (Glassdoor est.)    -1.0
# ...                             ...     ...
# ...

# %%
df['Salary Estimate'][0].split()
# Out:
# ['111', '-', '181', '(Glassdoor', 'est.)']

# %%
df['Salary Estimate'][0].split()[0]
# Out:
# '111'

# %%
df['Salary Estimate'][0].split()[2]
# Out:
# '181'

# %%
#ذخیره تغییرات ایجاد شده روی دیتا فریم تا به اینجا
#در مسیری که کار میکنیم ذخیره میشه
df.to_csv('my_dataframe.csv')

# %%
df=pd.read_csv('my_dataframe.csv')
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0                              Senior Data Scientist
# 1              1                  Data Scientist, Product Analytics
# 2              2                               Data Science Manager
# 3              3                                       Data Analyst
# 4              4                             Director, Data Science
# ...          ...                                                ...
# 5495        5881                              Information Scientist
# 5496        5882              Supervisory Research Health Scientist
# 5497        5883                  Senior SAS Programmer (Scientist)
# 5498        5886  Senior Data Analyst - Product Analytics (open ...
# 5499        5887                Manufacturing Data Analyst Engineer
#
#                     Salary Estimate  Rating  \
# 0       111 - 181  (Glassdoor est.)     3.5
# 1       111 - 181  (Glassdoor est.)     4.5
# ...

# %%
df['Salary Estimate'][0]
# Out:
# ' 111 - 181  (Glassdoor est.)'

# %%
def splitter(a):
    a=a.split()
    return a
splitter(df['Salary Estimate'][0])
df['Salary Estimate']=df['Salary Estimate'].apply(splitter)
df['Salary Estimate']
# Out:
# 0       [111, -, 181, (Glassdoor, est.)]
# 1       [111, -, 181, (Glassdoor, est.)]
# 2       [111, -, 181, (Glassdoor, est.)]
# 3       [111, -, 181, (Glassdoor, est.)]
# 4       [111, -, 181, (Glassdoor, est.)]
#                       ...
# 5495      [38, -, 64, (Glassdoor, est.)]
# 5496      [47, -, 89, (Glassdoor, est.)]
# 5497     [66, -, 113, (Glassdoor, est.)]
# 5498     [67, -, 111, (Glassdoor, est.)]
# 5499      [42, -, 76, (Glassdoor, est.)]
# Name: Salary Estimate, Length: 5500, dtype: object

# %%
def minfinder(a):
    a=a[0]
    return a
df['Min Salary']=df['Salary Estimate'].apply(minfinder)
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0                              Senior Data Scientist
# 1              1                  Data Scientist, Product Analytics
# 2              2                               Data Science Manager
# 3              3                                       Data Analyst
# 4              4                             Director, Data Science
# ...          ...                                                ...
# 5495        5881                              Information Scientist
# 5496        5882              Supervisory Research Health Scientist
# 5497        5883                  Senior SAS Programmer (Scientist)
# 5498        5886  Senior Data Analyst - Product Analytics (open ...
# 5499        5887                Manufacturing Data Analyst Engineer
#
#                        Salary Estimate  Rating  \
# 0     [111, -, 181, (Glassdoor, est.)]     3.5
# 1     [111, -, 181, (Glassdoor, est.)]     4.5
# ...

# %%
def maxfinder(a):
    a=a[2]
    return a
#maxfinder(df['Salary Estimate'][0])
df['Max Salary']=df['Salary Estimate'].apply(maxfinder)
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0                              Senior Data Scientist
# 1              1                  Data Scientist, Product Analytics
# 2              2                               Data Science Manager
# 3              3                                       Data Analyst
# 4              4                             Director, Data Science
# ...          ...                                                ...
# 5495        5881                              Information Scientist
# 5496        5882              Supervisory Research Health Scientist
# 5497        5883                  Senior SAS Programmer (Scientist)
# 5498        5886  Senior Data Analyst - Product Analytics (open ...
# 5499        5887                Manufacturing Data Analyst Engineer
#
#                        Salary Estimate  Rating  \
# 0     [111, -, 181, (Glassdoor, est.)]     3.5
# 1     [111, -, 181, (Glassdoor, est.)]     4.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5500 entries, 0 to 5499
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         5500 non-null   int64
#  1   Job Title          5500 non-null   object
#  2   Salary Estimate    5500 non-null   object
#  3   Rating             5500 non-null   float64
#  4   Company Name       5500 non-null   object
#  5   Location           5500 non-null   object
#  6   Size               5500 non-null   object
#  7   Founded            5500 non-null   object
#  8   Type of ownership  5500 non-null   object
#  9   Industry           5500 non-null   object
#  10  Sector             5500 non-null   object
#  11  Revenue            5500 non-null   object
#  12  Min Salary         5500 non-null   object
#  13  Max Salary         5500 non-null   object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 601.7+ KB

# %%
print(list(df.columns))
print(df.shape)
df.head(3)
# Out:
# ['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Rating', 'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Min Salary', 'Max Salary']
# (5500, 14)
#    Unnamed: 0                          Job Title  \
# 0           0              Senior Data Scientist
# 1           1  Data Scientist, Product Analytics
# 2           2               Data Science Manager
#
#                     Salary Estimate  Rating  Company Name      Location  \
# 0  [111, -, 181, (Glassdoor, est.)]     3.5   Hopper\n3.5  New York, NY
# 1  [111, -, 181, (Glassdoor, est.)]     4.5  Noom US\n4.5  New York, NY
# 2  [111, -, 181, (Glassdoor, est.)]    -1.0      Decode_M  New York, NY
#
#                      Size Founded  Type of ownership  \
# 0   501 to 1000 employees    2007  Company - Private
# 1  1001 to 5000 employees    2008  Company - Private
# 2       1 to 50 employees      -1            Unknown
#
# ...

# %%
#تغییر نوع داده استرینگ در ستون های مورد نظر به اینت تا بتون میانگین گرف
df['Min Salary']=df['Min Salary'].astype(int)
df['Max Salary']=df['Max Salary'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5500 entries, 0 to 5499
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         5500 non-null   int64
#  1   Job Title          5500 non-null   object
#  2   Salary Estimate    5500 non-null   object
#  3   Rating             5500 non-null   float64
#  4   Company Name       5500 non-null   object
#  5   Location           5500 non-null   object
#  6   Size               5500 non-null   object
#  7   Founded            5500 non-null   object
#  8   Type of ownership  5500 non-null   object
#  9   Industry           5500 non-null   object
#  10  Sector             5500 non-null   object
#  11  Revenue            5500 non-null   object
#  12  Min Salary         5500 non-null   int32
#  13  Max Salary         5500 non-null   int32
# dtypes: float64(1), int32(2), int64(1), object(10)
# memory usage: 558.7+ KB

# %%
df['Average_Salary']=(df['Min Salary']+df['Max Salary'])/2
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0                              Senior Data Scientist
# 1              1                  Data Scientist, Product Analytics
# 2              2                               Data Science Manager
# 3              3                                       Data Analyst
# 4              4                             Director, Data Science
# ...          ...                                                ...
# 5495        5881                              Information Scientist
# 5496        5882              Supervisory Research Health Scientist
# 5497        5883                  Senior SAS Programmer (Scientist)
# 5498        5886  Senior Data Analyst - Product Analytics (open ...
# 5499        5887                Manufacturing Data Analyst Engineer
#
#                        Salary Estimate  Rating  \
# 0     [111, -, 181, (Glassdoor, est.)]     3.5
# 1     [111, -, 181, (Glassdoor, est.)]     4.5
# ...

# %%
#تمیز کردن ستون لوکیشن
df['Location'].value_counts()
#میخواهیم  همه شهر های  ایالت ها را یکی کنیم و ایالت بمونه نه شهرها
# Out:
# Location
# Austin, TX          345
# Chicago, IL         333
# San Diego, CA       327
# New York, NY        303
# Los Angeles, CA     229
#                    ...
# Redlands, CA          1
# Ladera Ranch, CA      1
# Greenbelt, MD         1
# Lanham, MD            1
# Euclid, OH            1
# Name: count, Length: 501, dtype: int64

# %%
df['Location'][0]
# Out:
# 'New York, NY'

# %%
df['Location'][0].split()
# Out:
# ['New', 'York,', 'NY']

# %%
df['Location'][0].split()[-1]
# Out:
# 'NY'

# %%
def state(a):
    a=a.split()
    a=a[-1]
    return (a)
state(df['Location'][1000])
# Out:
# 'IL'

# %%
df['State']=df['Location'].apply(state)
df['State']
# Out:
# 0       NY
# 1       NY
# 2       NY
# 3       NJ
# 4       NY
#         ..
# 5495    OH
# 5496    OH
# 5497    OH
# 5498    OH
# 5499    OH
# Name: State, Length: 5500, dtype: object

# %%
df['State'].value_counts()
# Out:
# State
# CA         1311
# TX         1243
# OH          408
# IL          368
# PA          324
# NY          313
# AZ          297
# FL          261
# MA          239
# NJ          232
# MI          203
# VA          131
# DC           85
# MD           61
# DE           10
# Kingdom       4
# WI            3
# GA            1
# ME            1
# KY            1
# NM            1
# NH            1
# IN            1
# NC            1
# Name: count, dtype: int64

# %%
#با توجه به خروجی مرحله قبل به نظر می رسه که 
#kingdom
#اشتباهه و لازمه حذفش کنیم
df=df[df['State']!='Kingdom']
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0                              Senior Data Scientist
# 1              1                  Data Scientist, Product Analytics
# 2              2                               Data Science Manager
# 3              3                                       Data Analyst
# 4              4                             Director, Data Science
# ...          ...                                                ...
# 5495        5881                              Information Scientist
# 5496        5882              Supervisory Research Health Scientist
# 5497        5883                  Senior SAS Programmer (Scientist)
# 5498        5886  Senior Data Analyst - Product Analytics (open ...
# 5499        5887                Manufacturing Data Analyst Engineer
#
#                        Salary Estimate  Rating  \
# 0     [111, -, 181, (Glassdoor, est.)]     3.5
# 1     [111, -, 181, (Glassdoor, est.)]     4.5
# ...

# %%
#ستون های مهم باقی مانده دو ستون
#job title  , rating
#اهمیت بیشتری دارند ستون های دیگ هم هم هستند و میشه اطلاعات بیرون کشید اما اینا مهمترن
#ستون ریتینگ باسد بین 0 تا 5 باشه و منفی 1 غلطه لازمه حذف بشن
#اینو از قبل می دونیم
df['Rating'].value_counts()
df=df[df['Rating']!=-1]
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0                              Senior Data Scientist
# 1              1                  Data Scientist, Product Analytics
# 3              3                                       Data Analyst
# 4              4                             Director, Data Science
# 5              5                                     Data Scientist
# ...          ...                                                ...
# 5495        5881                              Information Scientist
# 5496        5882              Supervisory Research Health Scientist
# 5497        5883                  Senior SAS Programmer (Scientist)
# 5498        5886  Senior Data Analyst - Product Analytics (open ...
# 5499        5887                Manufacturing Data Analyst Engineer
#
#                        Salary Estimate  Rating  \
# 0     [111, -, 181, (Glassdoor, est.)]     3.5
# 1     [111, -, 181, (Glassdoor, est.)]     4.5
# ...

# %%
df['Job Title'].value_counts()
# Out:
# Job Title
# Data Scientist                                                   530
# Data Analyst                                                     296
# Data Engineer                                                    267
# Senior Data Scientist                                            117
# Machine Learning Engineer                                         55
#                                                                 ...
# Data Scientist - Top Secret w/ SCI Eligibility                     1
# Business Intelligence Analyst I                                    1
# Business Intelligence Analyst Senior (Chief Financial Office)      1
# Business Intelligence Analyst III - Credit Card                    1
# Manufacturing Data Analyst Engineer                                1
# Name: count, Length: 2552, dtype: int64

# %%
# جاب تایتل ها به صورت یونیک
set(df['Job Title'])
# Out:
# 4891

# %%
print(len(set(df['Job Title'])))
# Out:
# 2552

# %%
#تعداد دسته های  جاب تایتل ها خیلی زیاده میشه این ها رو به دسته های کوچیکتر تبدیل کرد
df.to_csv("my_dataframe2.csv")
